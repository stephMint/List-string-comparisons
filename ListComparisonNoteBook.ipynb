# %%
# import packages
import pandas as pd
import difflib

# %%
# concept exmaple
var_word = 'apple'
var_list = ['orange', 'ornge', 'ape', 'pear']

result = difflib.get_close_matches(var_word, var_list, 1, 0.7)
result
# Out:
# ['ape']

# %% [markdown]
# might need to lower case the strings in the check but not for the output. Maybe create a copy in a new array of the word checking array.

# %%
var_word.upper()
# Out:
# 'APPLE'
